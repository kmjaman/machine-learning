# %%
import pandas as pd

# %%
data = pd.read_csv('customer_churn.csv')

# %%
data.head(5)
# Out:
#    CustomerID  Age  Gender  Income  SubscriptionLength  NumComplaints  \
# 0        1001   25    Male   45000                  12              2
# 1        1002   30  Female   54000                  24              0
# 2        1003   22  Female   32000                   8              1
# 3        1004   40    Male   65000                  36              0
# 4        1005   35  Female   50000                  20              3
#
#     LastLogin Churn
# 0  2024-08-01    No
# 1  2024-08-10    No
# 2  2024-07-15   Yes
# 3  2024-08-12    No
# 4  2024-06-30   Yes

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
data['Gender'] = label_encoder.fit_transform(data['Gender'])

# %%
data['Churn'] = label_encoder.fit_transform(data['Churn'])

# %%
data['LastLogin'] = pd.to_datetime(data['LastLogin'])
data['DaysSinceLastLogin'] = (pd.to_datetime('2024-08-15') - data['LastLogin']).dt.days

# %%
data = data.drop(columns=['CustomerID', 'LastLogin'])

# %%
data.head(3)
# Out:
#    Age  Gender  Income  SubscriptionLength  NumComplaints  Churn  \
# 0   25       1   45000                  12              2      0
# 1   30       0   54000                  24              0      0
# 2   22       0   32000                   8              1      1
#
#    DaysSinceLastLogin
# 0                  14
# 1                   5
# 2                  31

# %%
from sklearn.model_selection import train_test_split

# %%
# Split the data into training and testing sets
X = data.drop('Churn', axis=1)
y = data['Churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#     Age  Gender  Income  SubscriptionLength  NumComplaints  DaysSinceLastLogin
# 8    33       1   57000                  22              0                   6
# 2    22       0   32000                   8              1                  31
# 1    30       0   54000                  24              0                   5
# 14   26       1   47000                  12              0                  31
# 4    35       0   50000                  20              3                  46

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=300)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=300)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
print(f'Accuracy: {accuracy}')
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# Accuracy: 0.8
# Confusion Matrix:
# [[3 0]
#  [1 1]]

# %%
new_data = pd.DataFrame({
    'Age': [30],
    'Gender': [1],  # Male
    'Income': [55000],
    'SubscriptionLength': [25],
    'NumComplaints': [1],
    'DaysSinceLastLogin': [5]  # Example feature
})

# %%
churn_prediction = model.predict(new_data)
print(f'Churn Prediction: {"Yes" if churn_prediction[0] == 1 else "No"}')
# Out:
# Churn Prediction: No
